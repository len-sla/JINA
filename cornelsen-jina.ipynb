# %% [markdown]
# Notebook for downloading n=number of pictures from the webpage with given search filter for the purpose of ML/NLP

# %% [markdown]
# # 1. Mounting google drive

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Standard snipet to prevent random disconnects
#
# This cell runs JS code to automatic reconnect to runtime.

# %%
import IPython
from google.colab import output

display(IPython.display.Javascript('''
 function ClickConnect(){
   btn = document.querySelector("colab-connect-button")
   if (btn != null){
     console.log("Click colab-connect-button"); 
     btn.click() 
     }
   
   btn = document.getElementById('ok')
   if (btn != null){
     console.log("Click reconnect"); 
     btn.click() 
     }
  }
  
setInterval(ClickConnect,60000)
'''))

print("Done.")
# Out:
# Done.

# %% [markdown]
# # 2. Loading required-libraries

# %%
# !pip install bing-image-downloader
from bing_image_downloader import downloader

# %% [markdown]
# # 3. Getting pictures

# %%
# query_string='Cornelsen Verlag  company profile people media data science'
# downloader.download(query_string, limit=150, output_dir='cornelsen', adult_filter_off=True, force_replace=False, timeout=60, verbose=True)

# %%
#@title Downloading pictures using bing search engine  { display-mode: "form" }

search_string = "Cornelsen" #@param [""] {allow-input: true}
nr_files_to_download = 350 #@param {type:"slider", min:0, max:1000, step:10}
out_directory = "/content/drive/MyDrive/JINA/cornel" #@param [""] {allow-input: true}


downloader.download(search_string, limit=nr_files_to_download, output_dir = out_directory, adult_filter_off=True, force_replace=False, timeout=60, verbose=True)
# Out:
# [%] Downloading Images to /content/drive/MyDrive/JINA/cornel/Cornelsen
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 150 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from https://www.heinlein-support.de/sites/default/files/cornelsen_0.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://campaign-image.eu/zohocampaigns/14ac0971ac_logo_cornelsen_ecademy.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://cheparev-portfolio.s3.amazonaws.com/images/download_4.86b854e2.fill-400x400-c100.png
# [%] File Downloaded !
#
# [%] Downloading Image #4 from https://www.internet-abc.de/fileadmin/_processed_/2/9/csm_cornelsen_clevery_oberstufe_600_01_b807dc120d.png
# [%] File Downloaded !
#
# [%] Downloading Image #5 from https://yt3.ggpht.com/a/AATXAJy4LMfAZB-iJZBEfTcxkRj1EqFvy1VrGtSJfA=s900-c-k-c0xffffffff-no-rj-mo
# [%] File Downloaded !
#
# [%] Downloading Image #6 from https://static.cornelsen.de/media/9783060620869/9783060620869_COVER_STD_B260_X2.png
# ...
